# %% [markdown]
# <a href="https://colab.research.google.com/github/nrenzan/AbstractiveTextSummarization/blob/main/Character_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handwritten optical character recognition

# %% [markdown]
# ---
#
# Optical Character recognition (OCR) with RNN Encoder-Decoder model. <br>
# The character recognition model will be trained in the notebook and the model will be used in several apps (iOS/Android) <br>
# <br>
# **Steps:**
#  * Imports and setups
#  * Data loading and preprocessing
#  * CTC setup
#  * Model setup and training
#  * Evaluation and analysis

# %% [markdown]
# # Importing and setup
# This step contains importing all needed libraries and defining hyperparameters and variables.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/DL/images.zip
# Out:
# Archive:  /content/drive/MyDrive/DL/images.zip
#    creating: images/
#   inflating: images/split.sh
#   inflating: images/generate_csv.sh
#    creating: images/train/
#   inflating: images/train/Codeine-2.png
#   inflating: images/train/Codeine-4.png
#   inflating: images/train/Dextropropoxyphene-1.png
#   inflating: images/train/Dextropropoxyphene-5.png
#   inflating: images/train/Ethylmorphine-5.png
#   inflating: images/train/Ethylmorphine-2.png
#   inflating: images/train/Ethylmorphine-1.png
#   inflating: images/train/Etorphine-4.png
#   inflating: images/train/Etorphine-3.png
#   inflating: images/train/Fentanyl-4.png
#   inflating: images/train/Fentanyl-5.png
#   inflating: images/train/Fentanyl-2.png
#   inflating: images/train/Methadone-2.png
#   inflating: images/train/Methadone-3.png
#   inflating: images/train/Methadone-4.png
#   inflating: images/train/Morphine-3.png
#   inflating: images/train/Morphine-5.png
#   inflating: images/train/Morphine-1.png
#   inflating: images/train/Phethidene-1.png
#   inflating: images/train/Phethidene-3.png
#   inflating: images/train/Pholcodine-4.png
#   inflating: images/train/Pholcodine-2.png
#   inflating: images/train/Buprenorphine-5.png
#   inflating: images/train/Buprenorphine-3.png
#   inflating: images/train/Buprenorphine-4.png
#   inflating: images/train/Buprenorphine-2.png
#   inflating: images/train/Glutethiamide-3.png
#   inflating: images/train/Glutethiamide-5.png
#   inflating: images/train/Glutethiamide-1.png
#   inflating: images/train/Glutethiamide-4.png
#   inflating: images/train/Pentazocine-3.png
#   inflating: images/train/Pentobarbital-1.png
#   inflating: images/train/Alprazolam-1.png
#   inflating: images/train/Chlordiazepoxide-3.png
#   inflating: images/train/Chlordiazepoxide-5.png
#   inflating: images/train/Chlordiazepoxide-4.png
#   inflating: images/train/Chlordiazepoxide-1.png
#   inflating: images/train/Clobazam-4.png
#   inflating: images/train/Clonazepam-1.png
#   inflating: images/train/Clonazepam-5.png
#   inflating: images/train/Diazepam-2.png
#   inflating: images/train/Diazepam-3.png
#   inflating: images/train/Flurazepam-3.png
#   inflating: images/train/Flurazepam-4.png
#   inflating: images/train/Lorazepam-1.png
#   inflating: images/train/Lorazepam-5.png
#   inflating: images/train/Medazepam-2.png
#   inflating: images/train/Medazepam-1.png
#   inflating: images/train/Medazepam-5.png
#   inflating: images/train/Meprobamate-2.png
#   inflating: images/train/Meprobamate-1.png
#   inflating: images/train/Meprobamate-3.png
#   inflating: images/train/Midazolam-2.png
#   inflating: images/train/Midazolam-4.png
#   inflating: images/train/Nitrazepam-3.png
#   inflating: images/train/Nitrazepam-5.png
#   inflating: images/train/Oxazepam-5.png
#   inflating: images/train/Oxazepam-4.png
#   inflating: images/train/Oxazolam-3.png
#   inflating: images/train/Oxazolam-1.png
#   inflating: images/train/Phenobarbital-1.png
#   inflating: images/train/Phenobarbital-2.png
#   inflating: images/train/Phenobarbital-3.png
#   inflating: images/train/Phentermine-3.png
#   inflating: images/train/Phentermine-4.png
#   inflating: images/train/Phentermine-2.png
#   inflating: images/train/Phentermine-5.png
#   inflating: images/train/Prazepam-4.png
#   inflating: images/train/Prazepam-2.png
#   inflating: images/train/Prazepam-1.png
#   inflating: images/train/Prazepam-5.png
#   inflating: images/train/Acetyl methadol-5.png
#   inflating: images/train/Acetyl methadol-4.png
#   inflating: images/train/Acetyl methadol-2.png
#   inflating: images/train/Acetyl methadol-3.png
#   inflating: images/train/Allyl prodine-4.png
#   inflating: images/train/Allyl prodine-2.png
#   inflating: images/train/Allyl prodine-3.png
#   inflating: images/train/Alpha acetyl methadol-2.png
#   inflating: images/train/Alpha acetyl methadol-1.png
#   inflating: images/train/Alpha meprodine-3.png
#   inflating: images/train/Alpha meprodine-5.png
#   inflating: images/train/Alpha meprodine-1.png
#   inflating: images/train/Alpha meprodine-4.png
#   inflating: images/train/Alpha methadol-5.png
#   inflating: images/train/Alpha methadol-1.png
#   inflating: images/train/Aceterphin hydrochloride-5.png
#   inflating: images/train/Acetyl dihydrocodeine-5.png
#   inflating: images/train/Acetyl dihydrocodeine-4.png
#   inflating: images/train/Acetyl dihydrocodeine-1.png
#   inflating: images/train/Alpha prodine-3.png
#   inflating: images/train/Alpha prodine-5.png
#   inflating: images/train/Alpha prodine-4.png
#   inflating: images/train/Acetyl dihydrocodinon-2.png
#   inflating: images/train/Acetyl dihydrocodinon-5.png
#   inflating: images/train/Apomorphine-3.png
#   inflating: images/train/Apomorphine-5.png
#   inflating: images/train/Apomorphine-1.png
#   inflating: images/train/Benzithidine-4.png
#   inflating: images/train/Bita acetyl methadol-1.png
#   inflating: images/train/Bita acetyl methadol-2.png
#   inflating: images/train/Bitameprodine-3.png
#   inflating: images/train/Bitameprodine-1.png
#   inflating: images/train/Bitameprodine-4.png
#   inflating: images/train/Bitamethadole-1.png
#   inflating: images/train/Bitamethadole-5.png
#   inflating: images/train/Bitamethadole-3.png
#   inflating: images/train/Bitamethadole-4.png
#   inflating: images/train/Bitaprodine-1.png
#   inflating: images/train/Bitaprodine-2.png
#   inflating: images/train/Bitaprodine-4.png
#   inflating: images/train/Bitaprodine-5.png
#   inflating: images/train/Benzyl morphine-5.png
#   inflating: images/train/Benzitramide-3.png
#   inflating: images/train/Benzitramide-5.png
#   inflating: images/train/Clonitazine-4.png
#   inflating: images/train/Clonitazine-3.png
#   inflating: images/train/Clonitazine-2.png
#   inflating: images/train/Codeine Methyl Bromide-4.png
#   inflating: images/train/Codeine Methyl Bromide-1.png
#   inflating: images/train/Codeine Methyl Bromide-3.png
#   inflating: images/train/Codeine Methyl Bromide-2.png
#   inflating: images/train/Codeine–N–oxide-4.png
#   inflating: images/train/Phitobemidone-4.png
#   inflating: images/train/Phitobemidone-1.png
#   inflating: images/train/Levomoramide-4.png
#   inflating: images/train/Levomoramide-3.png
#   inflating: images/train/Levomoramide-2.png
#   inflating: images/train/Levo phenacylemorphan-4.png
#   inflating: images/train/Levo phenacylemorphan-3.png
#   inflating: images/train/Levo metharphan-2.png
#   inflating: images/train/Levo metharphan-3.png
#   inflating: images/train/Levarphanole-3.png
#   inflating: images/train/Levarphanole-1.png
#   inflating: images/train/Levarphanole-5.png
#   inflating: images/train/Marpheridine-4.png
#   inflating: images/train/Marpheridine-5.png
#   inflating: images/train/Methyl desarphine-2.png
#   inflating: images/train/Methyl desarphine-3.png
#   inflating: images/train/Methyl desarphine-1.png
#   inflating: images/train/Methyl dihydromerphine-2.png
#   inflating: images/train/Morphine Methyl Bromide-2.png
#   inflating: images/train/Morphine Methyl Bromide-3.png
#   inflating: images/train/Morphine Methyl Bromide-5.png
#   inflating: images/train/Morphine Methyl Bromide-4.png
#   inflating: images/train/Morphine Methyl Bromide-1.png
#   inflating: images/train/Morphine–N–oxide-4.png
#   inflating: images/train/Morphine–N–oxide-2.png
#   inflating: images/train/Morphine–N–oxide-1.png
#   inflating: images/train/Myrophine-5.png
#   inflating: images/train/Metazosin-2.png
#   inflating: images/train/Moramide-5.png
#   inflating: images/train/Moramide-4.png
#   inflating: images/train/Nullophine-1.png
#   inflating: images/train/Nullophine-2.png
#   inflating: images/train/Naracymethadol-3.png
#   inflating: images/train/Naracymethadol-5.png
#   inflating: images/train/Narliverphenol-3.png
#   inflating: images/train/Narliverphenol-1.png
#   inflating: images/train/Narmethadone-1.png
#   inflating: images/train/Narmethadone-5.png
#   inflating: images/train/Narpipanone-1.png
#   inflating: images/train/Narpipanone-4.png
#   inflating: images/train/Nicocodeine-3.png
#   inflating: images/train/Nicocodeine-2.png
#   inflating: images/train/Nicocodeine-4.png
#   inflating: images/train/Nico morphine-4.png
#   inflating: images/train/Nico morphine-3.png
#   inflating: images/train/Nico morphine-1.png
#   inflating: images/train/Narmorphine-4.png
#   inflating: images/train/Narmorphine-5.png
#   inflating: images/train/Narmorphine-3.png
#   inflating: images/train/Narcodeine-4.png
#   inflating: images/train/Narcodeine-2.png
#   inflating: images/train/Oxymorphone-1.png
#   inflating: images/train/Opium-3.png
#   inflating: images/train/Opium-5.png
#   inflating: images/train/Phenadoxon-4.png
#   inflating: images/train/Phenadoxon-5.png
#   inflating: images/train/Phenadoxon-1.png
#   inflating: images/train/Phenampromide-3.png
#   inflating: images/train/Phenampromide-2.png
#   inflating: images/train/Phenampromide-5.png
#   inflating: images/train/Phenomorphan-2.png
#   inflating: images/train/Phenomorphan-4.png
#   inflating: images/train/Phenoperidine-2.png
#   inflating: images/train/Phenoperidine-1.png
#   inflating: images/train/Phenoperidine-5.png
#   inflating: images/train/Piritramide-5.png
#   inflating: images/train/Piritramide-3.png
#   inflating: images/train/Piritramide-1.png
#   inflating: images/train/Piritramide-4.png
#   inflating: images/train/Proheptazin-2.png
#   inflating: images/train/(e) cloxacillin-3.png
#   inflating: images/train/(e) cloxacillin-1.png
#   inflating: images/train/(e) cloxacillin-4.png
#   inflating: images/train/(f) Ampicillin-2.png
#   inflating: images/train/(f) Ampicillin-4.png
#   inflating: images/train/(f) Ampicillin-1.png
#   inflating: images/train/(g) Amoxycilin-3.png
#   inflating: images/train/(g) Amoxycilin-1.png
#   inflating: images/train/(a) Oxytetracyclline-4.png
#   inflating: images/train/(a) Oxytetracyclline-1.png
#   inflating: images/train/(a) Oxytetracyclline-5.png
#   inflating: images/train/(a) Oxytetracyclline-3.png
#   inflating: images/train/(b) Chlortetracycline-5.png
#   inflating: images/train/(b) Chlortetracycline-1.png
#   inflating: images/train/(b) Chlortetracycline-3.png
#   inflating: images/train/(c) Doxycycline-4.png
#   inflating: images/train/(c) Doxycycline-3.png
#   inflating: images/train/Gramicidine-2.png
#   inflating: images/train/Polymyxcin B-1.png
#   inflating: images/train/Polymyxcin B-5.png
#   inflating: images/train/Nistatin-1.png
#   inflating: images/train/Nistatin-2.png
#   inflating: images/train/Amphotericin B-4.png
#   inflating: images/train/Amphotericin B-3.png
#   inflating: images/train/Amphotericin B-5.png
#   inflating: images/train/Canamycin-2.png
#   inflating: images/train/Canamycin-5.png
#   inflating: images/train/Neo mycin-3.png
#   inflating: images/train/Neo mycin-5.png
#   inflating: images/train/Paramomycin-4.png
#   inflating: images/train/Paramomycin-5.png
#   inflating: images/train/Paramomycin-3.png
#   inflating: images/train/Paramomycin-2.png
#   inflating: images/train/Gentamycin-5.png
#   inflating: images/train/Gentamycin-4.png
#   inflating: images/train/Gentamycin-1.png
#   inflating: images/train/Erythromycin-4.png
#   inflating: images/train/Erythromycin-5.png
#   inflating: images/train/Erythromycin-2.png
#   inflating: images/train/Chloramphenicol-1.png
#   inflating: images/train/Chloramphenicol-3.png
#   inflating: images/train/Carbomycin-1.png
#   inflating: images/train/Carbomycin-3.png
#   inflating: images/train/Carbomycin-2.png
#   inflating: images/train/Faramycitine-2.png
#   inflating: images/train/Griseofulvin-3.png
#   inflating: images/train/Griseofulvin-2.png
#   inflating: images/train/Griseofulvin-4.png
#   inflating: images/train/Navobiocin-1.png
#   inflating: images/train/Navobiocin-2.png
#   inflating: images/train/Navobiocin-3.png
#   inflating: images/train/Navobiocin-5.png
#   inflating: images/train/Olindomycin-4.png
#   inflating: images/train/Olindomycin-3.png
#   inflating: images/train/Bancomycin-2.png
#   inflating: images/train/Bancomycin-1.png
#   inflating: images/train/Bancomycin-4.png
#   inflating: images/train/Benzocaine-1.png
#   inflating: images/train/Benzocaine-2.png
#   inflating: images/train/Ether-1.png
#   inflating: images/train/Ether-5.png
#   inflating: images/train/Ether-3.png
#   inflating: images/train/Ether-2.png
#   inflating: images/train/Luracine-2.png
#   inflating: images/train/Luracine-5.png
#   inflating: images/train/Halothane-4.png
#   inflating: images/train/Halothane-1.png
#   inflating: images/train/Halothane-5.png
#   inflating: images/train/Leaocane-3.png
#   inflating: images/train/Nitrous Oxide-5.png
#   inflating: images/train/Navobiocin.png
#   inflating: images/train/Neostigmine.png
#   inflating: images/train/N–ethyl–3 piparidyle Benzilet.png
#   inflating: images/train/Nico morphine.png
#   inflating: images/train/Nitrazepam.png
#   inflating: images/train/Nitrofurantoin.png
#   inflating: images/train/Noxmomica and Its Alcolides.png
#   inflating: images/train/Orthocaine.png
#   inflating: images/train/Oxazolam.png
#   inflating: images/train/Oxazolidine.png
#   inflating: images/train/Oxitocin.png
#   inflating: images/train/Oxymorphone.png
#   inflating: images/train/Paraldihyde.png
#   inflating: images/train/Paraleadoxin.png
#   inflating: images/train/Paramethadione.png
#   inflating: images/train/Paraminosolisilic Acid.png
#   inflating: images/train/Paramomycin.png
#   inflating: images/train/Pecazine.png
#   inflating: images/train/Peyot.png
#   inflating: images/train/Phenadoxon.png
#   inflating: images/train/Phenazocine.png
#   inflating: images/train/Phencyclidine.png
#   inflating: images/train/Phenmetrazine.png
#   inflating: images/train/Phenomorphan.png
#   inflating: images/train/Phenoperidine.png
#   inflating: images/train/Phenyl Butazone.png
#   inflating: images/train/Phenyl Cinchoninic Acid.png
#   inflating: images/train/Phethidene.png
#   inflating: images/train/Pholcodine.png
#   inflating: images/train/Pilocarpine.png
#   inflating: images/train/Piminodine.png
#   inflating: images/train/Procaine.png
#   inflating: images/train/Prochloro Perazine.png
#   inflating: images/train/Promethazine Hydrochloride.png
#   inflating: images/train/Propoxyphine.png
#   inflating: images/train/Provazine.png
#   inflating: images/train/Pyrivinium.png
#   inflating: images/train/Pyrizinamide.png
#   inflating: images/train/Recimoramide.png
#   inflating: images/train/Rifampin.png
#   inflating: images/train/Spironolactone.png
#   inflating: images/train/Spyromycin.png
#   inflating: images/train/Streptomycin.png
#   inflating: images/train/Sulfamethoxazole.png
# ...
#   inflating: images/validate/Triazolam-4.png
#   inflating: images/validate/Zolpidem-3.png
#   inflating: images/validate/Zolpidem-1.png
#   inflating: images/validate/Zolpidem-4.png
#   inflating: images/validate/Zolpidem-2.png
#   inflating: images/validate/Zolpidem-5.png
#   inflating: images/validate/Proparidine-5.png
#   inflating: images/validate/Proparidine-3.png
#   inflating: images/validate/Proparidine-2.png
#   inflating: images/validate/Proparidine-1.png
#   inflating: images/validate/Proparidine-4.png
#   inflating: images/validate/Recimoramide-1.png
#   inflating: images/validate/Recimoramide-4.png
#   inflating: images/validate/Recimoramide-5.png
#   inflating: images/validate/Recimoramide-3.png
#   inflating: images/validate/Recimoramide-2.png
#   inflating: images/validate/Recimeatharphan-5.png
#   inflating: images/validate/Recimeatharphan-3.png
#   inflating: images/validate/Recimeatharphan-2.png
#   inflating: images/validate/Recimorphan-1.png
#   inflating: images/validate/Recimorphan-4.png
#   inflating: images/validate/Recimorphan-3.png
#   inflating: images/validate/Recimorphan-2.png
#   inflating: images/validate/Trimeperidine-3.png
#   inflating: images/validate/Trimeperidine-1.png
#   inflating: images/validate/Trimeperidine-2.png
#   inflating: images/validate/Trimeperidine-5.png
#   inflating: images/validate/Trimeperidine-4.png
#   inflating: images/validate/Sulphone diethyl Methene-4.png
#   inflating: images/validate/Sulphone diethyl Methene-1.png
#   inflating: images/validate/Sulphone diethyl Methene-5.png
#   inflating: images/validate/Sulphone diethyl Methene-2.png
#   inflating: images/validate/Sulphone diethyl Methene-3.png
#   inflating: images/validate/Sulphone Methene-3.png
#   inflating: images/validate/Sulphone Methene-5.png
#   inflating: images/validate/Sulphone Methene-4.png
#   inflating: images/validate/Sulphone Methene-2.png
#   inflating: images/validate/Raolphia Alcolides-5.png
#   inflating: images/validate/Raolphia Alcolides-2.png
#   inflating: images/validate/Raolphia Alcolides-3.png
#   inflating: images/validate/Yohimba Alcolide-1.png
#   inflating: images/validate/Yohimba Alcolide-3.png
#   inflating: images/validate/Yohimba Alcolide-5.png
#   inflating: images/validate/Yohimba Alcolide-4.png
#   inflating: images/validate/Veratram Alcolide-5.png
#   inflating: images/validate/Veratram Alcolide-3.png
#   inflating: images/validate/Quinidine-1.png
#   inflating: images/validate/Quinidine-2.png
#   inflating: images/validate/Quinidine-3.png
#   inflating: images/validate/Quinidine-5.png
#   inflating: images/validate/Tropa cocane-3.png
#   inflating: images/validate/Tropa cocane-4.png
#   inflating: images/validate/Tropa cocane-5.png
#   inflating: images/validate/Vincristine-3.png
#   inflating: images/validate/Vincristine-4.png
#   inflating: images/validate/Vincristine-5.png
#   inflating: images/validate/Vincristine-1.png
#   inflating: images/validate/Vinblastine-3.png
#   inflating: images/validate/Vinblastine-4.png
#   inflating: images/validate/Vinblastine-2.png
#   inflating: images/validate/Vinblastine-5.png
#   inflating: images/validate/Vinblastine-1.png
#   inflating: images/validate/Troxidone-2.png
#   inflating: images/validate/Troxidone-4.png
#   inflating: images/validate/Troxidone-5.png
#   inflating: images/validate/Troxidone-3.png
#   inflating: images/validate/Troxidone-1.png
#   inflating: images/validate/Warfarin-3.png
#   inflating: images/validate/Warfarin-4.png
#   inflating: images/validate/Propoxyphine-4.png
#   inflating: images/validate/Propoxyphine-1.png
#   inflating: images/validate/Propoxyphine-3.png
#   inflating: images/validate/Triethinyl Thayo phosphoramide-3.png
#   inflating: images/validate/Triethinyl Thayo phosphoramide-2.png
#   inflating: images/validate/Triethinyl Thayo phosphoramide-5.png
#   inflating: images/validate/Stilbocaptate-2.png
#   inflating: images/validate/Stilbocaptate-5.png
#   inflating: images/validate/Stilbocaptate-3.png
#   inflating: images/validate/Stilbocaptate-4.png
#   inflating: images/validate/Zinc and it’s compound-1.png
#   inflating: images/validate/Zinc and it’s compound-2.png
#   inflating: images/validate/Zinc and it’s compound-4.png
#   inflating: images/validate/Zinc and it’s compound-3.png
#   inflating: images/validate/Zinc and it’s compound-5.png
#   inflating: images/validate/Sabidila Alcolide-5.png
#   inflating: images/validate/Sabidila Alcolide-2.png
#   inflating: images/validate/Sabidila Alcolide-3.png
#   inflating: images/validate/Sabidila Alcolide-1.png
#   inflating: images/validate/Sabidila Alcolide-4.png
#   inflating: images/validate/Thalium-4.png
#   inflating: images/validate/Thalium-1.png
#   inflating: images/validate/Thalium-3.png
#   inflating: images/validate/Thalium-5.png
#   inflating: images/validate/Sulfasomizole-1.png
#   inflating: images/validate/Sulfasalazine-3.png
#   inflating: images/validate/Sulfasalazine-5.png
#   inflating: images/validate/Sulfasalazine-2.png
#   inflating: images/validate/Sulfasalazine-4.png
#   inflating: images/validate/Tribromethanol-3.png
#   inflating: images/validate/Tribromethanol-5.png
#   inflating: images/validate/Tribromethanol-2.png
#   inflating: images/validate/Theopental Sodium-2.png
#   inflating: images/validate/Theopental Sodium-1.png
#   inflating: images/validate/Theopental Sodium-5.png
#   inflating: images/validate/Theopental Sodium-3.png
#   inflating: images/validate/Pyrizinamide-4.png
#   inflating: images/validate/Pyrizinamide-2.png
#   inflating: images/validate/Pyrizinamide-3.png
#   inflating: images/validate/Pyrizinamide-1.png
#   inflating: images/validate/Thiacetazone-1.png
#   inflating: images/validate/Thiacetazone-2.png
#   inflating: images/validate/Thiacetazone-4.png
#   inflating: images/validate/Protamine Sulphate-1.png
#   inflating: images/validate/Protamine Sulphate-5.png
#   inflating: images/validate/Protamine Sulphate-4.png
#   inflating: images/validate/Protamine Sulphate-3.png
#   inflating: images/validate/Protamine Sulphate-2.png
#   inflating: images/validate/Spironolactone-2.png
#   inflating: images/validate/Spironolactone-3.png
#   inflating: images/validate/Triamterene-4.png
#   inflating: images/validate/Triamterene-2.png
#   inflating: images/validate/Triamterene-3.png
#   inflating: images/validate/Triamterene-1.png
#   inflating: images/validate/Triethanolamine-3.png
#   inflating: images/validate/Triethanolamine-4.png
#   inflating: images/validate/Triethanolamine-1.png
#   inflating: images/validate/Triethanolamine-5.png
#   inflating: images/validate/Triethanolamine-2.png
#   inflating: images/validate/Vitamin D. as Single preparation-2.png
#   inflating: images/validate/Vitamin D. as Single preparation-1.png
#   inflating: images/validate/Vitamin D. as Single preparation-4.png
#   inflating: images/validate/Vitamin D. as Single preparation-3.png
#   inflating: images/validate/Pyrivinium-2.png
#   inflating: images/validate/Pyrivinium-3.png
#   inflating: images/validate/Pyrivinium-1.png
#   inflating: images/validate/Pyrivinium-4.png
#   inflating: images/validate/Pyrivinium-5.png
#   inflating: images/validate/Thiobendazole-2.png
#   inflating: images/validate/Thiobendazole-3.png
#   inflating: images/validate/Thiobendazole-1.png
#   inflating: images/validate/Verapamil Injection-1.png
#   inflating: images/validate/Verapamil Injection-4.png
#   inflating: images/validate/Verapamil Injection-3.png
#   inflating: images/validate/Verapamil Injection-2.png
#   inflating: images/validate/Triamipramine-5.png
#   inflating: images/validate/Triamipramine-1.png
#   inflating: images/validate/Triamipramine-2.png
#   inflating: images/validate/Triamipramine-4.png
#   inflating: images/validate/Triamipramine-3.png
#   inflating: images/validate/Trianyle Cipromine-3.png
#   inflating: images/validate/Trianyle Cipromine-5.png
#   inflating: images/validate/Trianyle Cipromine-2.png
#   inflating: images/validate/Trianyle Cipromine-1.png
#   inflating: images/validate/Trianyle Cipromine-4.png
#   inflating: images/validate/Promethazine Hydrochloride-5.png
#   inflating: images/validate/Promethazine Hydrochloride-1.png
#   inflating: images/validate/Promethazine Hydrochloride-2.png
#   inflating: images/validate/Promethazine Hydrochloride-3.png
#   inflating: images/validate/Provazine-3.png
#   inflating: images/validate/Provazine-2.png
#   inflating: images/validate/Provazine-1.png
#   inflating: images/validate/Triflupromazine-2.png
#   inflating: images/validate/Triflupromazine-5.png
#   inflating: images/validate/Triflupromazine-3.png
#   inflating: images/validate/Triflupromazine-1.png
#   inflating: images/validate/Theo Propazet-2.png
#   inflating: images/validate/Theo Propazet-4.png
#   inflating: images/validate/Theo Propazet-1.png
#   inflating: images/validate/Theo Propazet-5.png
#   inflating: images/validate/Prophen Pyridomine-5.png
#   inflating: images/validate/Prophen Pyridomine-2.png
#   inflating: images/validate/Prophen Pyridomine-3.png
#   inflating: images/validate/Sodium Amidotrizoate-4.png
#   inflating: images/validate/Sodium Amidotrizoate-2.png
#   inflating: images/validate/Sodium Amidotrizoate-5.png
#   inflating: images/validate/Tuberculin-3.png
#   inflating: images/validate/Tuberculin-2.png
#   inflating: images/validate/Tuberculin-1.png
#   inflating: images/validate/Stilboglucogate-3.png
#   inflating: images/validate/Stilboglucogate-1.png
#   inflating: images/validate/Stilboglucogate-4.png
#   inflating: images/validate/Stilboglucogate-5.png
#   inflating: images/validate/Stilboglucogate-2.png
#   inflating: images/validate/Talbutamide-2.png
#   inflating: images/validate/Talbutamide-4.png
#   inflating: images/validate/Talbutamide-1.png
#   inflating: images/validate/Talbutamide-5.png
#   inflating: images/validate/Suxamethonium-2.png
#   inflating: images/validate/Suxamethonium-3.png
#   inflating: images/validate/Suxamethonium-4.png
#   inflating: images/validate/Suxamethonium-1.png
#   inflating: images/validate/Suxamethonium-5.png
#   inflating: images/validate/Pyridostigmine-2.png
#   inflating: images/validate/Pyridostigmine-4.png
#   inflating: images/validate/Pyridostigmine-5.png
#   inflating: images/validate/Pyridostigmine-1.png
#   inflating: images/validate/Trihexyphenidyl-1.png
#   inflating: images/validate/Trihexyphenidyl-3.png
#   inflating: images/validate/Trihexyphenidyl-4.png
#   inflating: images/validate/Thyroid Extract & Thyroxin-5.png
#   inflating: images/validate/Thyroid Extract & Thyroxin-1.png
#   inflating: images/validate/Thyroid Extract & Thyroxin-3.png
#   inflating: images/validate/Vaso precin-1.png
#   inflating: images/validate/Vaso precin-2.png
#   inflating: images/validate/Vaso precin-5.png
#   inflating: images/validate/Vaso precin-3.png
#   inflating: images/validate/Vaso precin-4.png
#   inflating: images/validate/Acetyl dihydrocodinon.png
#   inflating: images/validate/Aminopterin.png
#   inflating: images/validate/Amitriptyline.png
#   inflating: images/validate/Arsenic and It’s compound.png
#   inflating: images/validate/Beladona & it’s Alcolide.png
#   inflating: images/validate/Benoctizine.png
#   inflating: images/validate/Benzitramide.png
#   inflating: images/validate/Bitaprodine.png
#   inflating: images/validate/Cantharidine.png
#   inflating: images/validate/Chlophazimine.png
#   inflating: images/validate/Chloropropamide.png
#   inflating: images/validate/Cloral Butane.png
#   inflating: images/validate/Cocaine.png
#   inflating: images/validate/Codeine.png
#   inflating: images/validate/Codeine–N–oxide.png
#   inflating: images/validate/(d) Dichloro Isopreterenol.png
#   inflating: images/validate/Dextran 40.png
#   inflating: images/validate/Diphenyl Pyraline Hydrochloride.png
#   inflating: images/validate/Disulphiram.png
#   inflating: images/validate/Dymethyl triptamin.png
#   inflating: images/validate/Endomethacin.png
#   inflating: images/validate/Ergot Alcolide and Its Derivatives.png
#   inflating: images/validate/Ethyl morphine.png
#   inflating: images/validate/(g) Amoxycilin.png
#   inflating: images/validate/Gramicidine.png
#   inflating: images/validate/Haloperidol.png
#   inflating: images/validate/Isosorbide Dinitrate or sorbide Nitrate.png
#   inflating: images/validate/Levo metharphan.png
#   inflating: images/validate/Phytomenadione.png
#   inflating: images/validate/Serum Protein.png
#   inflating: images/validate/Triazolam.png
#   inflating: images/validate/Zolpidem.png
#   inflating: images.zip
#   inflating: test.csv
#   inflating: train.csv
#   inflating: validate.csv

# %%
# import all tensorflow related libraries
import tensorflow as tf
import tensorflow.data as tfd
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# import other libraries
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
import matplotlib.pyplot as plt
import matplotlib.image as implt
from IPython.display import clear_output as cls

# %% [markdown]
# ## Defining the necessary variables

# %%
IMG_WIDTH = 200
IMG_HEIGHT = 50
IMG_SIZE = (IMG_WIDTH, IMG_HEIGHT)
BATCH_SIZE = 8
EPOCHS = 150
LEARNING_RATE = 1e-3
MODEL_NAME = "CharacterRecognition-Model"
TRAIN_SIZE = BATCH_SIZE * 3000
VALID_SIZE = BATCH_SIZE * 1500
TEST_SIZE  = BATCH_SIZE * 300
AUTOTUNE = tfd.AUTOTUNE

# Training callbacks
CALLBACKS = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ModelCheckpoint(filepath=MODEL_NAME + ".h5", save_best_only=True)
]

# Paths
train_csv_path = '/content/train.csv'
valid_csv_path = '/content/validate.csv'
test_csv_path = '/content/test.csv'
train_image_dir = '/content/images/train'
valid_image_dir = '/content/images/validate'
test_image_dir = '/content/images/test'

# SetUp random seeds for numpy and TensorFlow
np.random.seed(2569)
tf.random.set_seed(2569)

# %% [markdown]
# # Data loading and Preprocessing
# The datas are divided into 2 parts:
# * Labels and File paths
# * Images
# <br>
# There are some variables defined with `csv_path` at the end of their names. Those are the files that contain the **labels** and **file paths** for them. <br>
# The images are stored in the paths where their variables are defined with the ending of `image_dir`.
#
# ---
#
# First the `.csv` files are loaded. After that the labels and their file paths get extracted. After that, the labels are processed and the images are loaded based on the file names of the labels. At the end the images also get preprocessed to be ready for getting feeded to the model.

# %%
# load the csv files
train_csv = pd.read_csv(train_csv_path)[:TRAIN_SIZE]
test_csv = pd.read_csv(test_csv_path)[:TEST_SIZE]
valid_csv = pd.read_csv(valid_csv_path)[:VALID_SIZE]

# %%
train_csv.head()
# Out:
#                 FILENAME           IDENTITY
# 0  Dihydro Codeine-5.png  Dihydro Codeine-5
# 1         Procaine-2.png         Procaine-2
# 2      Bitaprodine-1.png      Bitaprodine-1
# 3           Procaine.png           Procaine
# 4    Buprenorphine-4.png    Buprenorphine-4

# %% [markdown]
# ### Load the train labels
# The labels will target the images. They basically attach a class to each image. <br>
# As mentioned before, the labels are in the `.csv` files in the column named `IDENTITY`. <br>

# %%
# get the train labels
train_labels = [str(word) for word in train_csv["IDENTITY"].to_numpy()]

# %%
# extract all the unique characters
unique_characters = set(char for word in train_labels for char in word)
# define the number of classes (for labels) based on the number of unique characters
n_classes = len(unique_characters)

# %%
print(f"Number of unique classes(unique characters): {n_classes}")
# Out:
# Number of unique classes(unique characters): 66

# %%
# get the maximum length that a label can have
MAX_LABEL_LENGTH = max(map(len, train_labels))

# %%
print(f"The length of the longest label in the datase: {MAX_LABEL_LENGTH}")
# Out:
# The length of the longest label in the datase: 49

# %% [markdown]
# ### Load the images paths
# In the `.csv` files, there paths for the images related to each label. However, there are only the names of the images. So, they have to preprocessed and the path of them must also be added to them. This step is crucial for loading images.

# %%
train_csv['FILENAME'] = [train_image_dir + f"/{filename}" for filename in train_csv['FILENAME']]
valid_csv['FILENAME'] = [valid_image_dir + f"/{filename}" for filename in valid_csv['FILENAME']]
test_csv['FILENAME']  = [test_image_dir + f"/{filename}" for filename in test_csv['FILENAME']]

# %%
train_csv.head()
# Out:
#                                       FILENAME           IDENTITY
# 0  /content/images/train/Dihydro Codeine-5.png  Dihydro Codeine-5
# 1         /content/images/train/Procaine-2.png         Procaine-2
# 2      /content/images/train/Bitaprodine-1.png      Bitaprodine-1
# 3           /content/images/train/Procaine.png           Procaine
# 4    /content/images/train/Buprenorphine-4.png    Buprenorphine-4

# %% [markdown]
# ## Label preprocessing
# 2 Dictionaries must be created. One for mapping characters to numerical values and one for mapping numerical values to characters

# %%
# Char to Num
char_to_num = StringLookup(vocabulary=list(unique_characters), mask_token=None)
num_to_char = StringLookup(vocabulary = char_to_num.get_vocabulary(), mask_token = None, invert = True)

# %%
len(char_to_num.get_vocabulary())+1
# Out:
# 68

# %% [markdown]
# ## Image preprocessing
# **To Function must be used for image preprocessing part:** <br>
# The first function is `load_image`. This function loads the images and returns the image as an `numpy` array. <br>
# The second function is used for both images and labels. It gets the data and returns the encoded versions of them.

# %%
def load_image(image_path):
    """
    This function gets the image path and
    reads the image using TensorFlow, Then the image will be decoded and
    will be converted to float data type. next resize and transpose will be applied to it.
    In the final step the image will be converted to a Numpy Array using tf.cast
    """
    # read the image
    image = tf.io.read_file(image_path)
    # decode the image
    decoded_image = tf.image.decode_jpeg(contents=image, channels=1)
    # convert image data type to float32
    convert_imgs = tf.image.convert_image_dtype(image=decoded_image, dtype=tf.float32)
    # resize and transpose
    resized_image = tf.image.resize(images=convert_imgs, size=(IMG_HEIGHT, IMG_WIDTH))
    image = tf.transpose(resized_image, perm = [1, 0, 2])

    # to numpy array (Tensor)
    image_array = tf.cast(image, dtype=tf.float32)

    return image_array

# %%
def encode_single_sample(image_path, label:str):

    '''
    The function takes an image path and label as input and returns a dictionary containing the processed image tensor and the label tensor.
    First, it loads the image using the load_image function, which decodes and resizes the image to a specific size. Then it converts the given
    label string into a sequence of Unicode characters using the unicode_split function. Next, it uses the char_to_num layer to convert each
    character in the label to a numerical representation. It pads the numerical representation with a special class (n_classes)
    to ensure that all labels have the same length (MAX_LABEL_LENGTH). Finally, it returns a dictionary containing the processed image tensor
    and the label tensor.

    '''

    # Get the image
    image = load_image(image_path)
    # Convert the label into characters
    chars = tf.strings.unicode_split(label, input_encoding='UTF-8')
    # Convert the characters into vectors
    vecs = char_to_num(chars)

    # Pad label
    pad_size = MAX_LABEL_LENGTH - tf.shape(vecs)[0]
    vecs = tf.pad(vecs, paddings = [[0, pad_size]], constant_values=n_classes+1)

    return {'image':image, 'label':vecs}

# %%
# Training Data
train_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(train_csv['FILENAME'].to_list()), np.array(train_csv['IDENTITY'].to_list()))
).shuffle(1000).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# Validation data
valid_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(valid_csv['FILENAME'].to_list()), np.array(valid_csv['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# Testing data.
test_ds = tf.data.Dataset.from_tensor_slices(
    (np.array(test_csv['FILENAME'].to_list()), np.array(test_csv['IDENTITY'].to_list()))
).map(encode_single_sample, num_parallel_calls=AUTOTUNE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# check the data distribution
print(f"Training Data Size   : {tf.data.Dataset.cardinality(train_ds).numpy() * BATCH_SIZE}")
print(f"Validation Data Size : {tf.data.Dataset.cardinality(valid_ds).numpy() * BATCH_SIZE}")
print(f"Testing Data Size    : {tf.data.Dataset.cardinality(test_ds).numpy() * BATCH_SIZE}")
# Out:
# Training Data Size   : 1600
# Validation Data Size : 312
# Testing Data Size    : 480

# %% [markdown]
# ### Explore the dataset
# See some images

# %%
def show_images(data, GRID=[4,4], FIGSIZE=(25, 8), cmap='binary_r', model=None, decode_pred=None):

    # Plotting configurations
    plt.figure(figsize=FIGSIZE)
    n_rows, n_cols = GRID

    # Loading Data
    data = next(iter(data))
    images, labels = data['image'], data['label']

    # Iterate over the data
    for index, (image, label) in enumerate(zip(images, labels)):

        # Label processing
        text_label = num_to_char(label)
        text_label = tf.strings.reduce_join(text_label).numpy().decode('UTF-8')
        text_label = text_label.replace("[UNK]", " ").strip()

        # Create a sub plot
        plt.subplot(n_rows, n_cols, index+1)
        plt.imshow(tf.transpose(image, perm=[1,0,2]), cmap=cmap)
        plt.axis('off')

        if model is not None and decode_pred is not None:
            # Make prediction
            pred = model.predict(tf.expand_dims(image, axis=0))
            pred = decode_pred(pred)[0]
            title = f"True : {text_label}\nPred : {pred}"
            plt.title(title)
        else:
            # add title
            plt.title(text_label)

    # Show the final plot
    cls()
    plt.show()

# %%
# train=pd.read_csv("/content/train.csv")

# %%
# train.head()

# %%
# train.shape

# %%
# for i in range(1,5):
  # df = train[~train['FILENAME'].str.contains(f'Hermons _–-{i}.png')]

# %%
# df.shape

# %%
# df.sum()

# %% [markdown]
# # Neural Net Model and Training
# The data has been readeed and preprocessed and everything is *go* for model training. <br>
#
# ---
#
# **There are 4 main sections in the model training part:**
# * CTC Loss (more explaination in its dedicated section)
# * Model Creation
# * Training
# * Testing and evaluation

# %% [markdown]
# ## CTC Loss
# ---
# ### Short Explaination:
# **The *Connectionist Temporal Classification*(CTC) loss is used for seq2seq tasks.** <br>
# In this case, the **CTC Loss** will take the ***Predicted Sequence of Characters*** and the ***label*** and calculates how far are they from each other. <br>
# The **other task** of CTC is to align the the length of predicted sequence and the label by addin blank spaces.
#
# ---
# ### Implementation:
# A class named `CTCLayer` is going to be defined. The input length and the predicted length are going to be taken. Then the loss

# %%
class CTCLayer(Layer):
    def __init__(self, **kwargs) -> None:
        super().__init__(**kwargs)

        # define the loss function
        self.loss_function = tf.keras.backend.ctc_batch_cost

    def call(self, y_true, y_hat):
        # Get the batch length
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")

        # get the input and label lengths
        input_len = tf.cast(tf.shape(y_hat)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')
        label_len = tf.cast(tf.shape(y_true)[1], dtype='int64') * tf.ones(shape=(batch_len, 1), dtype='int64')

        # calculate the loss
        loss = self.loss_function(y_true, y_hat, input_len, label_len)

        self.add_loss(loss)

        return y_hat

# %% [markdown]
# ## Model Creation
# The model used is a Encoder-Decoder Model which means it is a combinatio of CNN and RNN. <br>
#
# ---
#
# #### Model Architecture:
# The model has 2 Convolutional layers followed by MaxPools. <br>
# The encoding space has one Dense layer. The Decoder network is consist of 2 Bidirectional LSTM layers.

# %%
# Input Layer
input_images = Input(shape=(IMG_WIDTH, IMG_HEIGHT, 1), name="image")

# Labels : These are added for the training purpose.
input_labels = Input(shape=(None, ), name="label")

### Convolutional layers
# layer 1
conv_1 = Conv2D(64, 3, strides=1, padding="same", kernel_initializer="he_normal", activation="relu", name="conv_1")(input_images)
# layer 2
conv_2 = Conv2D(32, 3, strides=1, padding="same", kernel_initializer="he_normal", activation="relu", name="conv_2")(conv_1)
max_pool_1 = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv_2)
# layer 3
conv_3 = Conv2D(64, 3, strides=1, padding='same', activation='relu', kernel_initializer='he_normal', name="conv_3")(max_pool_1)
conv_4 = Conv2D(32, 3, strides=1, padding='same', activation='relu', kernel_initializer='he_normal', name="conv_4")(conv_3)
max_pool_2 = MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv_4)



### Encoding
reshape = Reshape(target_shape=((IMG_WIDTH//4), (IMG_HEIGHT//4)*32), name="reshape_layer")(max_pool_2)
dense_encoding = Dense(64, kernel_initializer="he_normal", activation="relu", name="enconding_dense")(reshape)
dense_encoding_2 = Dense(64, kernel_initializer="he_normal", activation="relu", name="enconding_dense_2")(dense_encoding)
dropout = Dropout(0.4)(dense_encoding_2)

# Decoder
lstm_1 = Bidirectional(LSTM(128, return_sequences=True, dropout=0.25), name="bidirectional_lstm_1")(dropout)
lstm_2 = Bidirectional(LSTM(64, return_sequences=True, dropout=0.25), name="bidirectional_lstm_2")(lstm_1)

# Final Output layer
output = Dense(len(char_to_num.get_vocabulary())+1, activation="softmax", name="output_dense")(lstm_2)

# Add the CTC loss
ctc_loss_layer = CTCLayer()(input_labels, output)

# Define the final model
model = Model(inputs=[input_images, input_labels], outputs=[ctc_loss_layer])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image (InputLayer)          [(None, 200, 50, 1)]         0         []
#
#  conv_1 (Conv2D)             (None, 200, 50, 64)          640       ['image[0][0]']
#
#  conv_2 (Conv2D)             (None, 200, 50, 32)          18464     ['conv_1[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 100, 25, 32)          0         ['conv_2[0][0]']
#  g2D)
#
#  conv_3 (Conv2D)             (None, 100, 25, 64)          18496     ['max_pooling2d_6[0][0]']
#
#  conv_4 (Conv2D)             (None, 100, 25, 32)          18464     ['conv_3[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 50, 12, 32)           0         ['conv_4[0][0]']
#  g2D)
#
#  reshape_layer (Reshape)     (None, 50, 384)              0         ['max_pooling2d_7[0][0]']
#
#  enconding_dense (Dense)     (None, 50, 64)               24640     ['reshape_layer[0][0]']
#
#  enconding_dense_2 (Dense)   (None, 50, 64)               4160      ['enconding_dense[0][0]']
#
#  dropout_3 (Dropout)         (None, 50, 64)               0         ['enconding_dense_2[0][0]']
#
#  bidirectional_lstm_1 (Bidi  (None, 50, 256)              197632    ['dropout_3[0][0]']
#  rectional)
#
#  bidirectional_lstm_2 (Bidi  (None, 50, 128)              164352    ['bidirectional_lstm_1[0][0]']
#  rectional)
#
#  label (InputLayer)          [(None, None)]               0         []
#
#  output_dense (Dense)        (None, 50, 68)               8772      ['bidirectional_lstm_2[0][0]']
#
#  ctc_layer_3 (CTCLayer)      (None, 50, 68)               0         ['label[0][0]',
#                                                                      'output_dense[0][0]']
#
# ==================================================================================================
# Total params: 455620 (1.74 MB)
# Trainable params: 455620 (1.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# draw the model plot
tf.keras.utils.plot_model(
    model,
    to_file='model-graph.png'
)

# %% [markdown]
# ### Model Training

# %%
# compile the model
model.compile(optimizer="adam")

# %%
# import pandas as pd
# import os
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# # Load CSV files containing file names for training and validation
# train_csv_file_path = '/content/train.csv'  # Replace with your train CSV file path
# valid_csv_file_path = '/content/validate.csv'  # Replace with your validation CSV file path

# train_data = pd.read_csv(train_csv_file_path)
# valid_data = pd.read_csv(valid_csv_file_path)

# # Directories containing images for training and validation
# train_image_directory = '/content/images/train'  # Replace with your train image directory path
# valid_image_directory = '/content/images/validate'  # Replace with your validation image directory path

# # Filter out file names that are not available in the image directories for training data
# train_existing_files = []
# for file_name in train_data['FILENAME']:
#     if os.path.exists(os.path.join(train_image_directory, file_name)):
#         train_existing_files.append(file_name)

# train_data = train_data[train_data['FILENAME'].isin(train_existing_files)]

# # Filter out file names that are not available in the image directories for validation data
# valid_existing_files = []
# for file_name in valid_data['FILENAME']:
#     if os.path.exists(os.path.join(valid_image_directory, file_name)):
#         valid_existing_files.append(file_name)

# valid_data = valid_data[valid_data['FILENAME'].isin(valid_existing_files)]

# # Create ImageDataGenerators for training and validation
# train_datagen = ImageDataGenerator(rescale=1./255)
# valid_datagen = ImageDataGenerator(rescale=1./255)

# # Create train and validation data generators using flow_from_dataframe
# train_ds = train_datagen.flow_from_dataframe(
#     dataframe=train_data,
#     directory=train_image_directory,
#     x_col="FILENAME",  # Replace with the column name containing file names in your train CSV
#     y_col="IDENTITY",  # Replace with your label column name in train CSV
#     batch_size=32,
#     seed=42,
#     shuffle=True,
#     class_mode="categorical",  # Adjust based on your task
#     # target_size=(image_height, image_width)  # Specify your image dimensions
# )

# valid_ds = valid_datagen.flow_from_dataframe(
#     dataframe=valid_data,
#     directory=valid_image_directory,
#     x_col="FILENAME",  # Replace with the column name containing file names in your validation CSV
#     y_col="IDENTITY",  # Replace with your label column name in validation CSV
#     batch_size=32,
#     seed=42,
#     shuffle=True,
#     class_mode="categorical",  # Adjust based on your task
#     # target_size=(image_height, image_width)  # Specify your image dimensions
# )

# # Define other necessary parameters (EPOCHS, CALLBACKS, etc.)
# EPOCHS = 10  # Replace with the desired number of epochs
# CALLBACKS = [ModelCheckpoint(filepath='model.h5', save_best_only=True), EarlyStopping(patience=3)]

# # Now, proceed with training the model using the separate datasets
# history = model.fit(train_ds, validation_data=valid_ds, epochs=EPOCHS, callbacks=CALLBACKS)

# %%
# train the model
history = model.fit(train_ds, validation_data=valid_ds, epochs=EPOCHS, callbacks=CALLBACKS)
# Out:
# Epoch 1/150
# 200/200 [==============================] - 151s 704ms/step - loss: 55.7402 - val_loss: 50.5046
# Epoch 2/150
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 149s 743ms/step - loss: 48.2485 - val_loss: 49.7203
# Epoch 3/150
# 200/200 [==============================] - 142s 709ms/step - loss: 47.3063 - val_loss: 49.0880
# Epoch 4/150
# 200/200 [==============================] - 141s 706ms/step - loss: 46.8617 - val_loss: 48.3458
# Epoch 5/150
# 200/200 [==============================] - 145s 725ms/step - loss: 46.6142 - val_loss: 47.9184
# Epoch 6/150
# 200/200 [==============================] - 142s 711ms/step - loss: 46.4607 - val_loss: 47.7498
# Epoch 7/150
# 200/200 [==============================] - 142s 709ms/step - loss: 46.2543 - val_loss: 47.4223
# Epoch 8/150
# 200/200 [==============================] - 174s 873ms/step - loss: 46.0988 - val_loss: 47.4141
# Epoch 9/150
# 200/200 [==============================] - 142s 710ms/step - loss: 46.0236 - val_loss: 47.6281
# Epoch 10/150
# 200/200 [==============================] - 141s 705ms/step - loss: 45.9375 - val_loss: 47.2984
# Epoch 11/150
# 200/200 [==============================] - 141s 705ms/step - loss: 45.7814 - val_loss: 47.0730
# Epoch 12/150
# 200/200 [==============================] - 132s 659ms/step - loss: 45.7434 - val_loss: 47.0741
# Epoch 13/150
# 200/200 [==============================] - 133s 665ms/step - loss: 45.6205 - val_loss: 46.8427
# Epoch 14/150
# 200/200 [==============================] - 142s 709ms/step - loss: 45.4192 - val_loss: 46.6875
# Epoch 15/150
# 200/200 [==============================] - 143s 715ms/step - loss: 45.2921 - val_loss: 46.8267
# Epoch 16/150
# 200/200 [==============================] - 145s 725ms/step - loss: 45.1666 - val_loss: 46.7212
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.legend(fontsize=15)
plt.xlabel("Epochs")
plt.ylabel("CTC Loss Score")
plt.title("Training and Validation Losses", fontsize=15)
plt.grid()
plt.savefig("model_result.png")
plt.show()

# %% [markdown]
# ## Testing and Evaluation

# %%
# evaluate the model on the test dataset
evaluation = model.evaluate(test_ds)
print(f"evaluation loss: {evaluation}")
# Out:
# 60/60 [==============================] - 11s 170ms/step - loss: 34.6118
# evaluation loss: 34.611751556396484

# %%
def decoder_prediction(pred_label):
    """
    This function has the job to decode the prediction that the model had.
    The model predicts each character and then this function makes it readable.
    """
    # Input length
    input_len = np.ones(shape=pred_label.shape[0]) * pred_label.shape[1]

    # CTC decode
    decode = tf.keras.backend.ctc_decode(pred_label, input_length=input_len, greedy=True)[0][0][:,:MAX_LABEL_LENGTH]

    # Converting numerics back to their character values
    chars = num_to_char(decode)

    # Join all the characters
    texts = [tf.strings.reduce_join(inputs=char).numpy().decode('UTF-8') for char in chars]

    # Remove the unknown token
    filtered_texts = [text.replace('[UNK]', " ").strip() for text in texts]

    return filtered_texts

# %%
# define a model for testing and evaluation
pred_model = Model(inputs=model.get_layer(name="image").input, outputs=model.get_layer(name='output_dense').output)

# %%
show_images(data=test_ds, model=pred_model, decode_pred=decoder_prediction, cmap='binary')

# %% [markdown]
# ### Single Sample prediction

# %%
def single_sample_prediction(model, path):
    """
    This function gets an image path and the model,
    Loads and preprocesses the image and make predictions on it.
    """
    # load image
    image_loading = tf.io.read_file(path)
    # decode image
    decoded_image = tf.image.decode_jpeg(contents=image_loading, channels=1)
    # convert the image data type to float
    convert_image = tf.image.convert_image_dtype(image=decoded_image, dtype=tf.float32)
    # resize the image
    resized_image = tf.image.resize(images=convert_image, size=(IMG_HEIGHT, IMG_WIDTH))
    resized_image = tf.transpose(resized_image, perm = [1, 0, 2])
    # convert image to array
    image_array = tf.cast(resized_image, dtype=tf.float32)
    # reshape image
    single_image_data_with_batch = np.expand_dims(image_array, axis=0)

    # make prediction
    prediction = decoder_prediction(model.predict(single_image_data_with_batch))

    return prediction

# %%
# prediction 1:
img_1_path = "/content/images/test/(a) Oxytetracyclline-2.png"
img_1 = implt.imread(img_1_path)
plt.imshow(img_1)
print(single_sample_prediction(pred_model, img_1_path))
# Out:
# 1/1 [==============================] - 0s 176ms/step
# ['C) ridine-3']

# %%
# prediction 2:
img_2_path = "/content/images/test/(a) Oxytetracyclline-2.png"
img_2 = implt.imread(img_2_path)
plt.imshow(img_2)
print(single_sample_prediction(pred_model, img_2_path))
# Out:
# 1/1 [==============================] - 0s 74ms/step
# ['C) ridine-3']

# %%
# prediction 3:
img_3_path = "/content/images/test/(c) Doxycycline-1.png"
img_3 = implt.imread(img_3_path)
plt.imshow(img_3)
print(single_sample_prediction(pred_model, img_3_path))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# ['() Pridine-3']

# %% [markdown]
# ### Saving the model

# %%
# save the model
model.save("model.hd5")
# save weights
model.save_weights("model_weights.hd5")

# %%
model.save('my_model.keras')
